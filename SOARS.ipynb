# %% [markdown]
# <b> This notebook is practice for analyzing data from CESM2 OMIP2 for SOARS Project </b>

# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# the line above is necessary for getting 
# your plot embedded within the notebook
# %matplotlib inline

dir = '/home/dallmann/'
fn_tos = 'tos_Omon_CESM2_omip2_r1i1p1f1_gn_030601-036612 (1).nc'

data_tos = xr.open_dataset(dir+fn_tos)
data_tos
# Out:
# /opt/miniconda3/envs/prod/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'tos' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# <xarray.Dataset>
# Dimensions:    (d2: 2, nlat: 384, nlon: 320, time: 732, vertices: 4)
# Coordinates:
#     lat        (nlat, nlon) float64 ...
#     lon        (nlat, nlon) float64 ...
#   * nlat       (nlat) int32 1 2 3 4 5 6 7 8 ... 377 378 379 380 381 382 383 384
#   * nlon       (nlon) int32 1 2 3 4 5 6 7 8 ... 313 314 315 316 317 318 319 320
#   * time       (time) object 0306-01-15 12:00:00 ... 0366-12-15 12:00:00
# Dimensions without coordinates: d2, vertices
# Data variables:
#     tos        (time, nlat, nlon) float32 ...
#     time_bnds  (time, d2) object ...
#     lat_bnds   (nlat, nlon, vertices) float32 ...
#     lon_bnds   (nlat, nlon, vertices) float32 ...
# Attributes: (12/46)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            OMIP
#     branch_method:          no parent
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  0.0
#     case_id:                1540
#     ...                     ...
#     tracking_id:            hdl:21.14100/0a0c1228-23e6-4c34-a08b-e6fc2b611ade
#     variable_id:            tos
#     variant_info:           CMIP6 omip2 experiment (JRA forcing) with interac...
#     variant_label:          r1i1p1f1
#     source_type:            OGCM BGC
#     comment:                Experiment run for 6 cycles of 1958-2018 JRA55 fo...

# %%
#convert the time into datetime64 

data_tos['time'] = data_tos.indexes['time'].to_datetimeindex(unsafe=True)
data_tos
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# /opt/miniconda3/envs/prod/lib/python3.8/site-packages/xarray/coding/times.py in cftime_to_nptime(times)
#     388             # datetime.datetime).
# --> 389             dt = pd.Timestamp(
#     390                 t.year, t.month, t.day, t.hour, t.minute, t.second, t.microsecond
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_datetime_to_tsobject()
#
# pandas/_libs/tslibs/np_datetime.pyx in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 306-01-15 12:00:00
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-7d3c7c321dbd> in <module>
#       1 #convert the time into datetime64
#       2
# ----> 3 data_tos['time'] = data_tos.indexes['time'].to_datetimeindex(unsafe=True)
#       4 data_tos
#
# /opt/miniconda3/envs/prod/lib/python3.8/site-packages/xarray/coding/cftimeindex.py in to_datetimeindex(self, unsafe)
#     625         DatetimeIndex(['2000-01-01', '2000-01-02'], dtype='datetime64[ns]', freq=None)
#     626         """
# --> 627         nptimes = cftime_to_nptime(self)
#     628         calendar = infer_calendar_name(self)
#     629         if calendar not in _STANDARD_CALENDARS and not unsafe:
#
# /opt/miniconda3/envs/prod/lib/python3.8/site-packages/xarray/coding/times.py in cftime_to_nptime(times)
#     391             )
#     392         except ValueError as e:
# --> 393             raise ValueError(
#     394                 "Cannot convert date {} to a date in the "
#     395                 "standard calendar.  Reason: {}.".format(t, e)
#
# ValueError: Cannot convert date 0306-01-15 12:00:00 to a date in the standard calendar.  Reason: Out of bounds nanosecond timestamp: 306-01-15 12:00:00.
